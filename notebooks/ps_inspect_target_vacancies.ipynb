# %%
import pandas as pd
import os

# %%
dataset = os.path.join('..', 'data', 'all_semcog_data_07-28-17.h5')
store = pd.HDFStore(dataset)

# %%
refiner = store['refiner_events']

# %%
refiner.loc[(refiner.year == 2016) & (refiner.action == 'add')]
# Out:
#               agent_expression  location_capacity_attribute  \
# refinement_id
# 2                sector_id==11                          NaN
# 5                 sector_id==5                          NaN
# 6                 sector_id==9                          NaN
# 7                 sector_id==9                          NaN
# 8                sector_id==11                          NaN
# 10                sector_id==3                          NaN
# 15                sector_id==6                          NaN
# 17                sector_id==5                          NaN
# 18                sector_id==5                          NaN
# 19                sector_id==5                          NaN
# 23                sector_id==4                          NaN
# 24                sector_id==5                          NaN
# 26                sector_id==9                          NaN
# 30               sector_id==10                          NaN
# ...
